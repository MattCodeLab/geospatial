# %%
import geopandas as gpd
import requests as r
import pandas as pd
import seaborn as sns
import pyarrow.parquet as pq
from geopy.geocoders import Nominatim
import time

url = "https://storage.dosm.gov.my/hies/hies_district.parquet"

# %%
hies_df = pd.read_parquet(url)

# %%
hies_df
hies_df['district'] = hies_df['district'].replace('W.P. Kuala Lumpur', 'Kuala Lumpur')
hies_df['state'] = hies_df['state'].replace('W.P. Kuala Lumpur', 'Kuala Lumpur')

# %%
geolocator = Nominatim(user_agent="my-gis-application")

# %%
unique_districts = hies_df['district'].unique()

# %%
coord_dict = {}

for district in unique_districts:
    try:
        # We add ", Malaysia" to make the search more specific
        location = geolocator.geocode(district + ", Malaysia")
        if location:
            coord_dict[district] = (location.latitude, location.longitude)
            print(f"Found {district}: ({location.latitude}, {location.longitude})")
        else:
            coord_dict[district] = (None, None)
            print(f"Could not find coordinates for {district}")
        
        # # Be nice to the server: wait 1 second between requests
        # time.sleep(1)
        
    except Exception as e:
        print(f"An error occurred for {district}: {e}")
        coord_dict[district] = (None, None)
# Out:
# Found Batu Pahat: (1.933333, 103.0)
# Found Johor Bahru: (1.4581986, 103.7649059)
# Found Kluang: (2.0323472, 103.3190766)
# Found Kota Tinggi: (1.7336743, 103.9006975)
# Found Mersing: (2.4298532, 103.835494)
# Found Muar: (2.0425046, 102.5658852)
# Found Pontian: (1.5, 103.5)
# Found Segamat: (2.4922852, 102.8450367)
# Found Kulai: (1.6666667, 103.6)
# Found Tangkak: (2.25, 102.5833333)
# Found Baling: (5.5507199, 100.797587)
# Found Bandar Baharu: (5.1672991, 100.5849347)
# Found Kota Setar: (6.122603, 100.3690317)
# Found Kuala Muda: (5.7073152, 100.4952892)
# Found Kubang Pasu: (6.3356376, 100.3723218)
# Found Kulim: (5.3707128, 100.6172071)
# Found Langkawi: (6.3700386, 99.7928634)
# Found Padang Terap: (6.2566513, 100.6645805)
# Found Sik: (5.9239011, 100.8231021)
# Found Yan: (5.8482755, 100.4151899)
# Found Pendang: (5.9720841, 100.5501852)
# Found Pokok Sena: (6.1730525, 100.5203915)
# Found Bachok: (5.9951191, 102.3867413)
# Found Kota Bharu: (6.1247911, 102.2378065)
# Found Machang: (5.7676702, 102.2380822)
# Found Pasir Mas: (6.0080942, 102.0925134)
# Found Pasir Puteh: (5.8346168, 102.3829644)
# Found Tanah Merah: (5.7663046, 102.0341478)
# Found Tumpat: (6.176396, 102.1663281)
# Found Gua Musang: (5.0198136, 102.0382663)
# Found Kuala Krai: (5.5311582, 102.1993666)
# Found Jeli: (5.5900186, 101.8171685)
# Found Kecil Lojing: (4.772153, 101.585769)
# Found Alor Gajah: (2.3834528, 102.2107805)
# Found Jasin: (2.3058097, 102.422339)
# Found Melaka Tengah: (2.2301451, 102.2453068)
# Found Jelebu: (3.0366264, 102.1179206)
# Found Kuala Pilah: (2.7430758, 102.2154881)
# Found Port Dickson: (2.5262491, 101.8106156)
# Found Rembau: (2.5578923, 102.1081637)
# Found Seremban: (2.723099, 101.9400601)
# Found Tampin: (2.5542371, 102.4459956)
# Found Jempol: (2.8502724, 102.5081957)
# Found Bentong: (3.3624708, 102.0172675)
# Found Cameron Highlands: (4.4781546, 101.4833091)
# Found Jerantut: (4.2834137, 102.5575232)
# Found Kuantan: (3.7985637, 103.32199)
# Found Lipis: (4.3242506, 101.9085845)
# Found Pekan: (3.4895509, 103.390396)
# Found Raub: (3.8843564, 101.7920275)
# Found Temerloh: (3.6124468, 102.2566818)
# Found Rompin: (2.8245772, 103.0993556)
# Found Maran: (3.601443, 102.6410048)
# Found Bera: (3.2366738, 102.5417723)
# Found Seberang Perai Tengah: (5.3610703, 100.4573584)
# Found Seberang Perai Utara: (5.4992806, 100.4467987)
# Found Seberang Perai Selatan: (5.2169636, 100.4804658)
# Found Timur Laut: (5.4103136, 100.2870311)
# Found Barat Daya: (5.3356587, 100.2389496)
# Found Batang Padang: (4.0833333, 101.3333333)
# Found Manjung: (4.334761, 100.6342662)
# Found Kinta: (4.5833333, 101.0833333)
# Found Kerian: (5.0345753, 100.4984585)
# Found Kuala Kangsar: (4.7720713, 100.9408776)
# Found Larut Dan Matang: (4.853766, 100.7436053)
# Found Hilir Perak: (4.0, 101.0)
# Found Hulu Perak: (5.4479728, 101.2971493)
# Found Perak Tengah: (4.25, 100.9166667)
# Found Kampar: (4.30066, 101.1614462)
# Found Muallim: (3.8333333, 101.5)
# Found Bagan Datuk: (3.9166667, 100.9166667)
# Found Selama: (5.2180903, 100.69166)
# Found Perlis: (6.4868392, 100.2577623)
# Found Gombak: (3.3, 101.7)
# Found Klang: (3.0448394, 101.4447363)
# Found Kuala Langat: (2.8365619, 101.4961821)
# Found Kuala Selangor: (3.3621022, 101.3455503)
# Found Petaling: (3.083333, 101.583333)
# Found Sabak Bernam: (3.6871153, 101.0580588)
# Found Sepang: (2.8008619, 101.7094012)
# Found Ulu Langat: (3.083333, 101.833333)
# Found Ulu Selangor: (3.5367441, 101.5949347)
# Found Besut: (5.5833333, 102.5)
# Found Dungun: (4.7643972, 103.4184463)
# Found Kemaman: (4.2395837, 103.1912607)
# Found Kuala Terengganu: (5.3296461, 103.1383265)
# Found Marang: (5.1666667, 103.1666667)
# Found Hulu Terengganu: (4.910689, 102.7650701)
# Found Setiu: (5.5500806, 102.7355111)
# Found Kuala Nerus: (5.3957398, 103.0615343)
# Found Tawau: (4.2435206, 117.885331)
# Found Lahad Datu: (5.1155093, 118.4306361)
# Found Semporna: (4.4790765, 118.4297732)
# Found Sandakan: (5.8391274, 118.1158598)
# Found Kinabatangan: (5.332648, 118.1212915)
# Found Beluran: (6.1366933, 117.3629228)
# Found Kota Kinabalu: (5.9780066, 116.0728988)
# Found Ranau: (5.8980313, 116.6696079)
# Found Kota Belud: (6.3347195, 116.4835961)
# Found Tuaran: (6.0659213, 116.3198111)
# Found Penampang: (5.8626228, 116.1138146)
# Found Papar: (5.7461495, 116.0449789)
# Found Kudat: (7.2316455, 117.1711562)
# Found Kota Marudu: (6.4465546, 116.828293)
# Found Pitas: (6.731706, 117.1254051)
# Found Beaufort: (5.2911244, 115.672474)
# Found Kuala Penyu: (5.4401919, 115.4949313)
# Found Sipitang: (4.634452, 115.6861012)
# Found Tenom: (4.9104025, 115.9050951)
# Found Nabawan: (4.6955329, 116.4837611)
# Found Keningau: (5.2179477, 116.2463149)
# Found Tambunan: (5.6860031, 116.4119595)
# Found Kunak: (4.6857678, 118.0170657)
# Found Tongod: (5.0657911, 116.9941053)
# Found Putatan: (5.8814478, 116.0656182)
# Found Telupid: (5.7903116, 117.1697573)
# Found Kalabakan: (4.4808936, 117.4071326)
# Found Kuching: (1.5597561, 110.345397)
# Found Bau: (1.417864, 110.1553336)
# Found Lundu: (1.6716097, 109.8536303)
# Found Samarahan: (1.434531, 110.4687843)
# Found Serian: (1.1136159, 110.6182211)
# Found Simunjan: (1.2756387, 110.8560923)
# Found Sri Aman: (1.2097123, 111.2866092)
# Found Lubok Antu: (1.0420707, 111.8332189)
# Found Betong: (1.4797292, 111.474787)
# Found Saratok: (1.7668371, 111.4087566)
# Found Sarikei: (2.1294846, 111.5230586)
# Found Maradong: (2.1685943, 111.6347075)
# Found Daro: (2.5139835, 111.432287)
# Found Julau: (1.8198041, 111.8990022)
# Found Sibu: (2.2996601, 111.8710012)
# Found Dalat: (2.701079, 111.960895)
# Found Mukah: (2.8118528, 112.291206)
# Found Kanowit: (1.9353301, 112.2098575)
# Found Bintulu: (3.1874261, 113.0472803)
# Found Tatau: (2.6234392, 113.1503927)
# Found Kapit: (2.0139027, 112.9356766)
# Found Song: (1.814243, 112.6478712)
# Found Belaga: (2.660919, 114.3816514)
# Found Miri: (4.3940102, 113.9880199)
# Found Marudi: (4.1795078, 114.3211018)
# Found Limbang: (4.3519985, 115.0602417)
# Found Lawas: (4.4551211, 115.427188)
# Found Matu: (2.6541259, 111.6853186)
# Found Asajaya: (1.5421712, 110.6127062)
# Found Pakan: (1.7829987, 111.6625798)
# Found Selangau: (2.4955896, 112.3524958)
# Found Tebedu: (1.0337681, 110.3931793)
# Found Pusa: (1.5447491, 111.11823)
# Found Kabong: (1.8856924, 111.2701566)
# Found Tanjung Manis: (2.1338299, 111.335745)
# Found Sebauh: (3.1175031, 113.2648667)
# Found Bukit Mabong: (1.7646775, 113.8410345)
# Found Subis: (3.7596364, 113.7142176)
# Found Beluru: (3.5515153, 114.1290552)
# Found Telang Usan: (3.3172316, 114.8258321)
# Found Kuala Lumpur: (3.1526589, 101.7022205)
# Found W.P. Labuan: (5.275699, 115.2328149)
# Found W.P. Putrajaya: (2.9179726, 101.6840801)

# %%
hies_df['latitude'] = hies_df['district'].map(lambda s: coord_dict.get(s, (None, None))[0])
hies_df['longitude'] = hies_df['district'].map(lambda s: coord_dict.get(s, (None, None))[1])

# %%
hies_df
# Out:
#            date           state        district  income_mean  income_median  \
# 0    2022-01-01           Johor      Batu Pahat         7419           6347
# 1    2022-01-01           Johor     Johor Bahru         9869           8232
# 2    2022-01-01           Johor          Kluang         6461           5204
# 3    2022-01-01           Johor     Kota Tinggi         7529           6227
# 4    2022-01-01           Johor         Mersing         5426           4445
# ..          ...             ...             ...          ...            ...
# 155  2022-01-01         Sarawak          Beluru         4873           4164
# 156  2022-01-01         Sarawak     Telang Usan         4692           3870
# 157  2022-01-01    Kuala Lumpur    Kuala Lumpur        13325          10234
# 158  2022-01-01     W.P. Labuan     W.P. Labuan         8250           6904
# 159  2022-01-01  W.P. Putrajaya  W.P. Putrajaya        13473          10056
#
#      expenditure_mean     gini  poverty  latitude   longitude
# 0                4570  0.33830      5.1  1.933333  103.000000
# 1                6139  0.35850      3.7  1.458199  103.764906
# 2                4399  0.35367      7.2  2.032347  103.319077
# 3                4498  0.34335      5.0  1.733674  103.900698
# 4                4032  0.33877     12.7  2.429853  103.835494
# ..                ...      ...      ...       ...         ...
# 155              2386  0.30156     13.7  3.551515  114.129055
# 156              2578  0.31077      6.0  3.317232  114.825832
# 157              7823  0.37960      1.4  3.152659  101.702220
# 158              4176  0.30028      2.5  5.275699  115.232815
# 159              8897  0.36780      0.1  2.917973  101.684080
#
# [160 rows x 10 columns]

# %%
gdf = gpd.GeoDataFrame(
    hies_df,
    geometry=gpd.points_from_xy(hies_df['longitude'], hies_df['latitude']),
    crs="EPSG:4326"
)
gdf.to_file('hies_geocoded_auto.gpkg', driver='GPKG')
